# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:02, 12.1MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count / total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold / freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size + 1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx + 1:stop + 1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6412 0.0948 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6509 0.0886 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5268 0.0883 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5864 0.0878 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4943 0.0883 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5344 0.0892 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5437 0.0857 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5417 0.0867 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4611 0.0848 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3960 0.0872 sec/batch
# Nearest to one: wait, overgrown, nanos, that, handled, bambino, succesor, wi,
# Nearest to been: gba, machismo, millionth, leonards, integrals, blanket, factsheet, leary,
# Nearest to united: quota, bootstrapping, goblet, lo, demolition, tinymux, accelerating, thrown,
# Nearest to their: gaudy, leeson, testifying, advanced, neuronal, granta, electrification, alas,
# Nearest to known: filioque, lunches, vientiane, presumed, colle, bazille, bulb, impotence,
# Nearest to states: kuk, lenny, munin, adel, exposure, elysium, coy, relatively,
# Nearest to at: excitatory, facades, purposes, polk, felice, judgments, retired, daredevil,
# Nearest to other: investigation, louisiana, jerome, perle, ge, teixeira, powerpc, zambia,
# Nearest to report: contain, tfl, karachi, fingertips, pocket, surrounding, bioengineering, couldn,
# Nearest to instance: disengagement, karabakh, vilnius, decomposers, crankshafts, plight, burgundy, settler,
# Nearest to animals: lenin, ockham, graphing, abrahams, gssps, umami, collated, quicktime,
# Nearest to event: fb, semitic, artichokes, cetacean, poached, tentative, suggestive, scientologists,
# Nearest to paris: beliefs, honeycomb, bellows, para, prefetch, tley, carlyle, armour,
# Nearest to existence: mishandled, thracian, tamerlane, adoption, citations, prizes, gladiator, precondition,
# Nearest to governor: cohomology, inserting, distinguished, kir, vil, flightless, heading, wm,
# Nearest to running: preacher, vices, injure, singers, recaptured, kestrels, salaries, googolplex,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4992 0.0848 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3974 0.0811 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3457 0.0913 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2334 0.0884 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1584 0.0866 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1387 0.0805 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0668 0.0865 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0617 0.0817 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9822 0.0785 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9699 0.0829 sec/batch
# Nearest to one: wait, worth, accordingly, completion, appeared, overgrown, handled, keep,
# Nearest to been: gba, central, integrals, suggestion, lower, little, millionth, remainder,
# Nearest to united: lo, quota, thrown, demolition, like, laws, accelerating, beacon,
# Nearest to their: advanced, leeson, loaded, testifying, babylon, gaudy, granta, ensuring,
# Nearest to known: colle, presumed, y, structures, word, generating, vms, concentrations,
# Nearest to states: relatively, appeared, revived, kuk, exposure, appeal, well, reluctant,
# Nearest to at: purposes, retired, excitatory, polk, daredevil, judgments, marxism, singh,
# Nearest to other: investigation, ge, louisiana, jerome, mostly, organizations, perle, gallery,
# Nearest to report: contain, surrounding, traveling, karachi, compound, roots, couldn, pocket,
# Nearest to instance: vilnius, questioned, alloying, dewey, esl, plight, settler, disengagement,
# Nearest to animals: lenin, rebirth, collated, coordinate, dollars, graphing, abrahams, ockham,
# Nearest to event: cetacean, semitic, sunrise, fb, scientologists, tentative, within, instructional,
# Nearest to paris: beliefs, controlled, bellows, honeycomb, lorna, para, prefetch, armour,
# Nearest to existence: mishandled, adoption, thracian, lenten, gladiator, prizes, textile, corsican,
# Nearest to governor: cohomology, distinguished, inserting, fend, heading, pages, hunter, bite,
# Nearest to running: singers, preacher, vices, injure, conduct, salaries, ciudad, duration,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9398 0.0904 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9013 0.0872 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8781 0.0872 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8704 0.0891 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8172 0.0907 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8343 0.0868 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8097 0.0826 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7709 0.0859 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8002 0.0846 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7763 0.0848 sec/batch
# Nearest to one: worth, wait, usta, completion, americas, succesor, longest, kurds,
# Nearest to been: millionth, lower, integrals, blanket, central, gba, mistreatment, liberating,
# Nearest to united: demolition, lo, quota, thrown, accelerating, cuba, byzantine, like,
# Nearest to their: advanced, loaded, testifying, leeson, granta, physician, gaudy, ensuring,
# Nearest to known: presumed, colle, filioque, y, earns, word, limitation, ev,
# Nearest to states: lenny, revived, appeared, elysium, exposure, relatively, appeal, kuk,
# Nearest to at: excitatory, retired, purposes, marxism, felice, polk, judgments, tournament,
# Nearest to other: jerome, investigation, emissions, organizations, vast, perle, louisiana, ge,
# Nearest to report: contain, surrounding, harbour, pocket, drops, ensure, karachi, compound,
# Nearest to instance: vilnius, disengagement, esl, settler, nationality, dewey, earners, plight,
# Nearest to animals: lenin, rebirth, gssps, graphing, peers, dualistic, collated, quicktime,
# Nearest to event: semitic, fb, cetacean, tentative, sunrise, scientologists, instructional, nicene,
# Nearest to paris: beliefs, bellows, para, honeycomb, prefetch, armour, carlyle, lorna,
# Nearest to existence: mishandled, adoption, prizes, gladiator, thracian, lenten, textile, quarks,
# Nearest to governor: inserting, cohomology, distinguished, fend, heading, hunter, pages, legacy,
# Nearest to running: singers, preacher, vices, injure, conduct, salaries, gsm, thirteen,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7741 0.0882 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7684 0.0871 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7271 0.0868 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7150 0.0875 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7517 0.0846 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6934 0.0844 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7282 0.0887 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7256 0.0827 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7030 0.0912 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6687 0.0877 sec/batch
# Nearest to one: zero, laureate, nobel, kurds, regret, usta, eight, james,
# Nearest to been: millionth, lower, liberating, mistreatment, gba, integrals, bushy, leonards,
# Nearest to united: cuba, lo, quota, headquarters, demolition, goblet, mendelian, thrown,
# Nearest to their: advanced, testifying, loaded, granta, leeson, ensuring, gaudy, accommodating,
# Nearest to known: presumed, colle, filioque, earns, teaser, hershey, vientiane, lunches,
# Nearest to states: elysium, lenny, kuk, neon, ojibwe, indulgent, reluctant, revived,
# Nearest to at: excitatory, retired, polk, felice, marxism, facades, tournament, singh,
# Nearest to other: jerome, emissions, investigation, organizations, caching, lute, backfired, vast,
# Nearest to report: contain, karachi, harbour, surrounding, pocket, tfl, ensure, carom,
# Nearest to instance: disengagement, vilnius, settler, esl, hou, earners, karabakh, plight,
# Nearest to animals: lenin, graphing, rebirth, collated, gssps, injections, dualistic, abrahams,
# Nearest to event: fb, semitic, cetacean, tentative, sunrise, scientologists, profoundly, nicene,
# Nearest to paris: beliefs, honeycomb, bellows, prefetch, armour, opposes, para, carlyle,
# Nearest to existence: mishandled, thracian, tamerlane, adoption, gladiator, prizes, lenten, quarks,
# Nearest to governor: inserting, fend, cohomology, hunter, austrian, heading, legacy, distinguished,
# Nearest to running: preacher, singers, injure, vices, recaptured, salaries, micrometres, thirteen,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6925 0.0850 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6697 0.0864 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6188 0.0893 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6060 0.0866 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6017 0.0840 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6375 0.0855 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5927 0.0633 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5650 0.0878 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5256 0.0850 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5116 0.0873 sec/batch
# Nearest to one: laureate, nobel, pianist, zero, eight, singer, chemist, seven,
# Nearest to been: millionth, liberating, discreet, lower, impeached, roadway, takes, cyclo,
# Nearest to united: cuba, lo, headquarters, demolition, quota, fukuoka, goblet, byzantine,
# Nearest to their: granta, advanced, testifying, loaded, ibis, alas, gaudy, sheik,
# Nearest to known: presumed, colle, filioque, earns, lunches, hershey, bulb, potato,
# Nearest to states: elysium, kuk, lenny, ojibwe, indulgent, coy, acquisition, austronesian,
# Nearest to at: excitatory, retired, polk, felice, facades, policia, marxism, lat,
# Nearest to other: emissions, backfired, jerome, organisational, organizations, investigation, caching, vast,
# Nearest to report: contain, karachi, harbour, ensure, carom, surrounding, carbides, pocket,
# Nearest to instance: disengagement, hou, esl, vilnius, karabakh, settler, cautionary, countable,
# Nearest to animals: lenin, injections, graphing, endorsements, rebirth, dualistic, collated, gssps,
# Nearest to event: fb, semitic, cetacean, poached, tentative, profoundly, suggestive, scientologists,
# Nearest to paris: beliefs, honeycomb, prefetch, armour, opposes, carlyle, para, bellows,
# Nearest to existence: mishandled, tamerlane, quarks, rejoin, thracian, gladiator, adoption, covert,
# Nearest to governor: fend, playful, austrian, hunter, cohomology, auctioned, hapsburg, bite,
# Nearest to running: injure, preacher, vices, deontological, recaptured, singers, micrometres, salaries,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5064 0.0867 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5092 0.0863 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4747 0.0802 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5063 0.0833 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5010 0.0847 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4915 0.0827 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4295 0.0878 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3932 0.0835 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4362 0.0862 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4375 0.0871 sec/batch
# Nearest to one: zero, usta, nobel, pianist, laureate, barron, phil, wait,
# Nearest to been: millionth, liberating, cyclo, impeached, discreet, bushy, directorate, inflaming,
# Nearest to united: cuba, headquarters, quota, lo, bootstrapping, fukuoka, goblet, demolition,
# Nearest to their: loaded, granta, advanced, ibis, accommodating, testifying, damage, sheik,
# Nearest to known: presumed, colle, filioque, hershey, word, lunches, bulb, earns,
# Nearest to states: elysium, kuk, austronesian, ojibwe, acquisition, indulgent, lenny, coy,
# Nearest to at: excitatory, retired, polk, facades, policia, felice, petitioner, tournament,
# Nearest to other: emissions, organisational, caching, use, backfired, jerome, investigation, weights,
# Nearest to report: contain, karachi, carom, ensure, programmability, tfl, pocket, carbides,
# Nearest to instance: hou, karabakh, esl, disengagement, countable, vilnius, bipolar, cautionary,
# Nearest to animals: injections, dualistic, endorsements, graphing, lenin, rebirth, collated, gssps,
# Nearest to event: fb, semitic, nicene, poached, tentative, cetacean, sunrise, artichokes,
# Nearest to paris: prefetch, beliefs, honeycomb, spiderweb, armour, possessive, para, lorna,
# Nearest to existence: quarks, tamerlane, rejoin, mishandled, thracian, adoption, gladiator, covert,
# Nearest to governor: playful, fend, hunter, hapsburg, auctioned, austrian, bite, lashed,
# Nearest to running: injure, deontological, vices, preacher, micrometres, recaptured, slick, gsm,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4331 0.0865 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4222 0.0905 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4261 0.0857 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4002 0.0859 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4227 0.0884 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4449 0.0873 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3833 0.0881 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4011 0.0864 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4511 0.0882 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3871 0.0900 sec/batch
# Nearest to one: zero, nobel, laureate, barron, pianist, restorations, seven, johns,
# Nearest to been: millionth, inflaming, directorate, discreet, mistreatment, cyclo, bushy, impeached,
# Nearest to united: cuba, quota, headquarters, jamaica, laws, baghd, bootstrapping, national,
# Nearest to their: granta, loaded, ibis, sheik, advanced, attainment, testifying, alas,
# Nearest to known: presumed, colle, bulb, filioque, potato, hershey, teaser, lunches,
# Nearest to states: elysium, austronesian, kuk, ojibwe, acquisition, provisions, exceptions, spd,
# Nearest to at: excitatory, policia, retired, facades, polk, felice, petitioner, hyper,
# Nearest to other: caching, emissions, organisational, outward, assumption, jerome, powerpc, use,
# Nearest to report: contain, karachi, ensure, carom, programmability, vez, carbides, problems,
# Nearest to instance: disengagement, hou, karabakh, countable, bipolar, esl, cautionary, nyquist,
# Nearest to animals: injections, endorsements, dualistic, graphing, deporting, gssps, layer, collated,
# Nearest to event: fb, semitic, poached, sunrise, tentative, profoundly, comprehend, nicene,
# Nearest to paris: prefetch, honeycomb, sandhurst, possessive, spiderweb, armour, lorna, para,
# Nearest to existence: quarks, tamerlane, rejoin, mishandled, adoption, disapproved, ffff, thracian,
# Nearest to governor: playful, fend, hapsburg, auctioned, hunter, austrian, lashed, kir,
# Nearest to running: deontological, injure, slick, vices, preacher, micrometres, gsm, recaptured,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3834 0.0893 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3991 0.0907 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3855 0.0891 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3968 0.0887 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3724 0.0873 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3544 0.0881 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4011 0.0878 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4025 0.0876 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3465 0.0888 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3476 0.0893 sec/batch
# Nearest to one: zero, seven, three, eight, barron, two, restorations, johns,
# Nearest to been: mistreatment, millionth, discreet, directorate, inflaming, bushy, liberating, grounds,
# Nearest to united: cuba, headquarters, quota, baghd, jamaica, bootstrapping, laws, increasingly,
# Nearest to their: ibis, granta, loaded, damage, accommodating, sheik, ensuring, disinterested,
# Nearest to known: presumed, colle, filioque, potato, hershey, word, antichrist, binet,
# Nearest to states: elysium, provisions, acquisition, austronesian, ojibwe, republics, spd, kuk,
# Nearest to at: excitatory, policia, polk, retired, since, facades, petitioner, purposes,
# Nearest to other: caching, emissions, outward, vast, organisational, jerome, organizations, powerpc,
# Nearest to report: contain, ensure, carom, torontonians, karachi, programmability, problems, pro,
# Nearest to instance: disengagement, karabakh, hou, bipolar, cautionary, esl, vilnius, countable,
# Nearest to animals: injections, dualistic, endorsements, graphing, gssps, layer, deporting, helices,
# Nearest to event: fb, sunrise, semitic, poached, nicene, tentative, profoundly, cetacean,
# Nearest to paris: honeycomb, prefetch, possessive, sandhurst, lorna, spiderweb, cosby, desolate,
# Nearest to existence: quarks, mishandled, rejoin, tamerlane, adoption, ffff, principle, precondition,
# Nearest to governor: hapsburg, fend, playful, vote, auctioned, district, lashed, purged,
# Nearest to running: injure, deontological, slick, preacher, toolkit, vices, micrometres, gsm,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3628 0.0896 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2682 0.0898 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3622 0.0867 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3585 0.0885 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4032 0.0886 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2893 0.0872 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2835 0.0877 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3388 0.0872 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2350 0.0898 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3082 0.0872 sec/batch
# Nearest to one: zero, seven, eight, three, two, laureate, recipient, barron,
# Nearest to been: inflaming, millionth, suggestion, mistreatment, directorate, bushy, liberating, cyclo,
# Nearest to united: cuba, quota, headquarters, jamaica, baghd, news, increasingly, international,
# Nearest to their: granta, ibis, accommodating, sheik, attainment, alas, damage, loaded,
# Nearest to known: hershey, colle, presumed, filioque, potato, bulb, word, vientiane,
# Nearest to states: elysium, austronesian, republics, kuk, ojibwe, provisions, censor, in,
# Nearest to at: excitatory, policia, facades, since, retired, petitioner, polk, felice,
# Nearest to other: caching, emissions, vast, bolivia, organisational, weights, sw, volusia,
# Nearest to report: contain, ensure, torontonians, carom, pro, perpetrators, karachi, programmability,
# Nearest to instance: disengagement, karabakh, cautionary, bipolar, esl, hou, intercal, countable,
# Nearest to animals: injections, dualistic, endorsements, graphing, layer, rebirth, gssps, helices,
# Nearest to event: fb, sunrise, poached, profoundly, planting, cetacean, upwards, suggestive,
# Nearest to paris: prefetch, honeycomb, possessive, cosby, sandhurst, monaghan, lorna, migne,
# Nearest to existence: quarks, tamerlane, mishandled, rejoin, principle, adoption, ffff, thracian,
# Nearest to governor: fend, hapsburg, vote, purged, vil, lashed, playful, auctioned,
# Nearest to running: injure, deontological, slick, toolkit, seasons, gsm, preacher, micrometres,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2888 0.0892 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2946 0.0901 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3418 0.0415 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2587 0.0886 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2278 0.0909 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2130 0.0901 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2125 0.0852 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2088 0.0856 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2212 0.0874 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1921 0.0879 sec/batch
# Nearest to one: zero, three, two, eight, seven, laureate, barron, nobel,
# Nearest to been: suggestion, inflaming, millionth, cyclo, mistreatment, directorate, grounds, liberating,
# Nearest to united: cuba, quota, jamaica, headquarters, baghd, international, newspapers, news,
# Nearest to their: granta, ibis, accommodating, attainment, damage, alveoli, sheik, assassins,
# Nearest to known: colle, potato, hershey, vientiane, presumed, filioque, bulb, word,
# Nearest to states: elysium, austronesian, kuk, censor, appeal, provisions, acquisition, republics,
# Nearest to at: policia, excitatory, since, retired, polk, petitioner, felice, facades,
# Nearest to other: caching, bolivia, organisational, sw, emissions, outward, vast, valerian,
# Nearest to report: contain, ensure, torontonians, carom, pro, perpetrators, programmability, problems,
# Nearest to instance: disengagement, cautionary, karabakh, bipolar, esl, deletions, hou, gaetana,
# Nearest to animals: dualistic, injections, graphing, endorsements, mammals, justifies, deporting, molokai,
# Nearest to event: fb, poached, sunrise, cetacean, planting, comprehend, artichokes, suggestive,
# Nearest to paris: prefetch, cosby, sandhurst, possessive, honeycomb, desolate, lorna, migne,
# Nearest to existence: quarks, rejoin, tamerlane, principle, mishandled, idealism, ffff, destinies,
# Nearest to governor: fend, hapsburg, vil, vote, auctioned, purged, playful, lashed,
# Nearest to running: injure, deontological, slick, toolkit, seasons, attendances, gsm, micrometres,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2340 0.0877 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2353 0.0885 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2314 0.0864 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1379 0.0888 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1809 0.0870 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1422 0.0862 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1823 0.0873 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1705 0.0879 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2032 0.0875 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1732 0.0913 sec/batch
# Nearest to one: zero, two, three, eight, seven, four, five, barron,
# Nearest to been: suggestion, millionth, inflaming, grounds, directorate, grey, cyclo, liberating,
# Nearest to united: cuba, quota, baghd, headquarters, jamaica, beacon, velasco, news,
# Nearest to their: ibis, accommodating, granta, it, attainment, alveoli, alas, damage,
# Nearest to known: potato, colle, hershey, bulb, presumed, vientiane, structures, stallion,
# Nearest to states: elysium, austronesian, acquisition, appeal, ojibwe, censor, kuk, provisions,
# Nearest to at: excitatory, policia, since, petitioner, retired, facades, purposes, polk,
# Nearest to other: caching, valerian, emissions, publically, sap, bolivia, goings, weights,
# Nearest to report: contain, ensure, carom, persons, perpetrators, dupont, problems, torontonians,
# Nearest to instance: disengagement, karabakh, cautionary, bipolar, deletions, hou, vary, nyquist,
# Nearest to animals: dualistic, injections, graphing, mammals, humans, fertilization, chimpanzees, endorsements,
# Nearest to event: fb, poached, planting, nicene, sunrise, comprehend, suggestive, remnants,
# Nearest to paris: prefetch, sandhurst, cosby, possessive, honeycomb, migne, haute, lorna,
# Nearest to existence: quarks, principle, rejoin, idealism, ffff, tamerlane, mishandled, adoption,
# Nearest to governor: fend, vote, hapsburg, vil, playful, auctioned, lashed, voters,
# Nearest to running: injure, deontological, toolkit, slick, seasons, attendances, gsm, oakland,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1691 0.0884 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2454 0.0857 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1707 0.0889 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1578 0.0889 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1779 0.0878 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1535 0.0858 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1805 0.0905 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1288 0.0863 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1497 0.0815 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2047 0.0796 sec/batch
# Nearest to one: zero, two, eight, three, seven, four, five, nine,
# Nearest to been: suggestion, millionth, mistreatment, grounds, inflaming, directorate, bushy, integrals,
# Nearest to united: cuba, quota, headquarters, jamaica, velasco, baghd, beacon, newspapers,
# Nearest to their: ibis, granta, accommodating, puppets, alas, attainment, gamers, alveoli,
# Nearest to known: potato, colle, bulb, presumed, hershey, vientiane, stallion, structures,
# Nearest to states: austronesian, elysium, acquisition, appeal, provisions, in, censor, exceptions,
# Nearest to at: excitatory, since, policia, petitioner, facades, retired, felice, unsold,
# Nearest to other: caching, publically, emissions, valerian, outward, jerome, volusia, bolivia,
# Nearest to report: contain, ensure, thumbnails, perpetrators, carom, usenet, torontonians, keynes,
# Nearest to instance: disengagement, karabakh, cautionary, hou, deletions, bipolar, vilnius, vary,
# Nearest to animals: dualistic, injections, mammals, humans, graphing, fertilization, chimpanzees, endorsements,
# Nearest to event: fb, planting, nicene, imager, poached, upwards, sunrise, circumvented,
# Nearest to paris: sandhurst, prefetch, possessive, haute, cosby, migne, dictionnaire, honeycomb,
# Nearest to existence: quarks, principle, rejoin, dimmu, idealism, mishandled, occultism, tamerlane,
# Nearest to governor: fend, vote, hapsburg, voters, kava, lashed, vil, district,
# Nearest to running: toolkit, deontological, injure, slick, seasons, attendances, hedley, gsm,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2158 0.0904 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1635 0.0891 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1631 0.0878 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1978 0.0869 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1536 0.0882 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1298 0.0876 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1783 0.0863 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1436 0.0880 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2015 0.0871 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1800 0.0891 sec/batch
# Nearest to one: zero, two, three, eight, seven, nine, five, four,
# Nearest to been: suggestion, mistreatment, grounds, millionth, bushy, inquisitor, inflaming, directorate,
# Nearest to united: cuba, quota, jamaica, headquarters, velasco, baghd, u, beacon,
# Nearest to their: ibis, granta, accommodating, ruthless, hellish, zsa, worshipers, testifying,
# Nearest to known: potato, colle, presumed, hershey, vientiane, barada, is, bulb,
# Nearest to states: in, appeal, elysium, acquisition, censor, austronesian, provisions, concluded,
# Nearest to at: policia, since, excitatory, felice, retired, petitioner, polk, facades,
# Nearest to other: jerome, caching, publically, bolivia, valerian, volusia, emissions, hamelin,
# Nearest to report: contain, torontonians, perpetrators, pro, persons, ensure, thumbnails, pl,
# Nearest to instance: disengagement, karabakh, cautionary, deletions, vary, hou, vilnius, esl,
# Nearest to animals: mammals, dualistic, humans, injections, graphing, chimpanzees, fertilization, endorsements,
# Nearest to event: fb, planting, poached, sunrise, boldness, upwards, yama, nicene,
# Nearest to paris: haute, possessive, prefetch, sandhurst, migne, dictionnaire, cosby, karamanlis,
# Nearest to existence: quarks, principle, tamerlane, occultism, rejoin, idealism, dimmu, mishandled,
# Nearest to governor: fend, hapsburg, vil, district, kava, vote, lashed, gothicus,
# Nearest to running: toolkit, injure, slick, deontological, hedley, attendances, seasons, recaptured,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2152 0.0889 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1119 0.0881 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1524 0.0918 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1564 0.0888 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0416 0.0871 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1254 0.0859 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1317 0.0885 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1323 0.0884 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1929 0.0161 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0873 0.0867 sec/batch
# Nearest to one: zero, eight, three, two, seven, four, nine, five,
# Nearest to been: suggestion, mistreatment, grounds, diaries, millionth, grey, extraction, inquisitor,
# Nearest to united: cuba, quota, jamaica, headquarters, velasco, baghd, beacon, gunnery,
# Nearest to their: ibis, granta, busway, accommodating, ruthless, puppets, alas, dwellers,
# Nearest to known: potato, colle, hershey, vientiane, presumed, structures, bulb, stallion,
# Nearest to states: appeal, acquisition, ojibwe, in, austronesian, provisions, elysium, censor,
# Nearest to at: policia, since, excitatory, facades, retired, felice, petitioner, purposes,
# Nearest to other: caching, publically, valerian, volusia, bolivia, emissions, jerome, organisational,
# Nearest to report: contain, perpetrators, thumbnails, dupont, pro, persons, pl, torontonians,
# Nearest to instance: disengagement, cautionary, nyquist, q, deletions, momenta, vary, esl,
# Nearest to animals: mammals, humans, dualistic, chimpanzees, graphing, fertilization, injections, skirmish,
# Nearest to event: fb, planting, poached, suggestive, boldness, seating, upwards, sunrise,
# Nearest to paris: haute, prefetch, sandhurst, possessive, karamanlis, migne, honeycomb, cosby,
# Nearest to existence: quarks, principle, occultism, tamerlane, dimmu, idealism, rejoin, cantor,
# Nearest to governor: fend, hapsburg, vil, vote, district, terengganu, kava, gothicus,
# Nearest to running: toolkit, injure, deontological, slick, hedley, attendances, seasons, oakland,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0881 0.0883 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0810 0.0836 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0762 0.0795 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0702 0.0863 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0806 0.0875 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0546 0.0877 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1079 0.0892 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0980 0.0909 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0989 0.0859 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0349 0.0864 sec/batch
# Nearest to one: zero, three, two, eight, seven, four, five, nine,
# Nearest to been: suggestion, grounds, cyclo, grey, extraction, millionth, inquisitor, inflaming,
# Nearest to united: cuba, jamaica, quota, velasco, headquarters, renewal, baghd, u,
# Nearest to their: ibis, accommodating, granta, busway, ruthless, dwellers, alas, replayed,
# Nearest to known: colle, potato, hershey, vientiane, presumed, bulb, stallion, allegories,
# Nearest to states: acquisition, appeal, united, austronesian, provisions, ojibwe, unitary, censor,
# Nearest to at: policia, since, excitatory, retired, felice, purposes, petitioner, unsold,
# Nearest to other: caching, bolivia, publically, valerian, jerome, volusia, sap, calves,
# Nearest to report: contain, perpetrators, thumbnails, dupont, usenet, persons, muller, pro,
# Nearest to instance: disengagement, deletions, cautionary, vary, momenta, karabakh, hou, esl,
# Nearest to animals: humans, dualistic, mammals, chimpanzees, graphing, injections, fertilization, skirmish,
# Nearest to event: fb, planting, boldness, poached, nicene, comprehend, suggestive, yama,
# Nearest to paris: haute, prefetch, possessive, dictionnaire, sandhurst, migne, karamanlis, cosby,
# Nearest to existence: quarks, principle, tamerlane, occultism, rejoin, dimmu, idealism, destinies,
# Nearest to governor: fend, vote, terengganu, hapsburg, district, voters, vil, gothicus,
# Nearest to running: toolkit, injure, deontological, slick, hedley, attendances, headset, core,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0305 0.0882 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0456 0.0841 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0177 0.0837 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0575 0.0833 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0741 0.0826 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0819 0.0840 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0849 0.0853 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1367 0.0868 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0443 0.0840 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0488 0.0828 sec/batch
# Nearest to one: zero, three, two, eight, seven, five, four, nine,
# Nearest to been: suggestion, grounds, diaries, grey, extraction, bestowed, inquisitor, millionth,
# Nearest to united: cuba, jamaica, velasco, quota, u, states, headquarters, beacon,
# Nearest to their: ibis, accommodating, puppets, dwellers, alveoli, busway, sha, gamers,
# Nearest to known: colle, potato, presumed, hershey, bulb, vientiane, stallion, allegories,
# Nearest to states: acquisition, united, provisions, appeal, unitary, ojibwe, austronesian, wellness,
# Nearest to at: since, policia, excitatory, purposes, diploma, felice, petitioner, enrollment,
# Nearest to other: caching, jerome, publically, valerian, sap, bolivia, preventable, volusia,
# Nearest to report: contain, dupont, thumbnails, muller, extract, perpetrators, usenet, recommends,
# Nearest to instance: disengagement, deletions, cautionary, momenta, karabakh, vary, q, hou,
# Nearest to animals: mammals, humans, dualistic, chimpanzees, graphing, skirmish, fertilization, injections,
# Nearest to event: fb, comprehend, planting, nicene, poached, boldness, imager, suggestive,
# Nearest to paris: dictionnaire, haute, prefetch, possessive, sandhurst, karamanlis, migne, vend,
# Nearest to existence: quarks, principle, idealism, empiricists, occultism, cantor, dimmu, rejoin,
# Nearest to governor: hapsburg, district, terengganu, fend, vote, voters, kir, perot,
# Nearest to running: toolkit, injure, slick, hedley, deontological, headset, attendances, receiver,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0829 0.0840 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1118 0.0813 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0663 0.0801 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0523 0.0816 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0740 0.0835 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0469 0.0832 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0791 0.0836 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0634 0.0838 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0730 0.0845 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0605 0.0843 sec/batch
# Nearest to one: zero, eight, two, three, seven, four, nine, five,
# Nearest to been: suggestion, inquisitor, diaries, grounds, directorate, bestowed, last, rescind,
# Nearest to united: cuba, jamaica, u, velasco, quota, states, headquarters, renewal,
# Nearest to their: ibis, busway, lepers, sha, puppets, worshipers, saxons, ruthless,
# Nearest to known: colle, potato, presumed, hershey, stallion, is, vientiane, allegories,
# Nearest to states: united, provisions, appeal, acquisition, unitary, reluctant, readmitted, censor,
# Nearest to at: since, policia, excitatory, purposes, diploma, felice, zurich, overlord,
# Nearest to other: jerome, valerian, publically, caching, bolivia, in, perle, adherents,
# Nearest to report: dupont, contain, muller, thumbnails, perpetrators, biographies, extract, pl,
# Nearest to instance: disengagement, cautionary, karabakh, vary, deletions, momenta, q, settler,
# Nearest to animals: mammals, humans, chimpanzees, dualistic, graphing, fertilization, injections, skirmish,
# Nearest to event: fb, nicene, comprehend, planting, boldness, infinity, suggestive, yama,
# Nearest to paris: haute, dictionnaire, vend, karamanlis, sandhurst, france, arta, prefetch,
# Nearest to existence: quarks, principle, idealism, empiricists, occultism, dimmu, cantor, rejoin,
# Nearest to governor: hapsburg, fend, terengganu, district, perot, kir, vote, advice,
# Nearest to running: toolkit, injure, hedley, deontological, slick, core, attendances, headset,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0557 0.0866 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0049 0.0839 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0373 0.0850 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0746 0.0808 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0616 0.0815 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1260 0.0839 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1362 0.0838 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0182 0.0843 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0309 0.0774 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0816 0.0799 sec/batch
# Nearest to one: zero, two, eight, three, four, seven, five, nine,
# Nearest to been: diaries, inquisitor, suggestion, grounds, bestowed, unmentioned, extraction, rescind,
# Nearest to united: cuba, jamaica, quota, velasco, u, states, gunnery, baghd,
# Nearest to their: ibis, puppets, sha, busway, lepers, worshipers, gamers, dwellers,
# Nearest to known: colle, potato, presumed, hershey, allegories, stallion, structures, vientiane,
# Nearest to states: united, provisions, reluctant, appeal, acquisition, unitary, ojibwe, hamdi,
# Nearest to at: since, policia, diploma, felice, zurich, excitatory, overlord, students,
# Nearest to other: caching, bolivia, valerian, jerome, publically, sw, sap, feroze,
# Nearest to report: contain, dupont, biographies, perpetrators, thumbnails, extract, muller, pl,
# Nearest to instance: disengagement, cautionary, karabakh, deletions, vary, vilnius, momenta, comcast,
# Nearest to animals: mammals, humans, chimpanzees, dualistic, graphing, skirmish, fertilization, injections,
# Nearest to event: fb, boldness, planting, seating, nicene, coincide, suggestive, atp,
# Nearest to paris: haute, dictionnaire, vend, arta, karamanlis, france, migne, prefetch,
# Nearest to existence: idealism, principle, quarks, empiricists, dimmu, occultism, destinies, cantor,
# Nearest to governor: hapsburg, terengganu, district, perot, kir, fend, daron, auctioned,
# Nearest to running: toolkit, injure, hedley, slick, deontological, core, headset, seasons,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9741 0.0833 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0501 0.0850 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0234 0.0817 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0133 0.0842 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0937 0.0854 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0364 0.0782 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0204 0.0843 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9959 0.0837 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0303 0.0872 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9749 0.0905 sec/batch
# Nearest to one: zero, eight, two, three, nine, seven, five, four,
# Nearest to been: diaries, suggestion, unmentioned, inquisitor, bestowed, extraction, grounds, grey,
# Nearest to united: cuba, jamaica, states, u, velasco, quota, baghd, beacon,
# Nearest to their: ibis, dwellers, puppets, busway, gamers, lepers, sha, warhammer,
# Nearest to known: colle, potato, presumed, allegories, stallion, hershey, is, vientiane,
# Nearest to states: united, reluctant, acquisition, appeal, provisions, ojibwe, unitary, hamdi,
# Nearest to at: since, policia, zurich, overlord, diploma, felice, dates, enrollment,
# Nearest to other: valerian, caching, jerome, bolivia, sap, gnawing, in, calves,
# Nearest to report: contain, thumbnails, dupont, biographies, perpetrators, muller, extract, pl,
# Nearest to instance: cautionary, disengagement, deletions, vary, q, karabakh, subverted, momenta,
# Nearest to animals: humans, mammals, chimpanzees, dualistic, skirmish, graphing, wolves, fertilization,
# Nearest to event: fb, boldness, nicene, seating, planting, comprehend, coincide, lingered,
# Nearest to paris: haute, dictionnaire, arta, france, migne, karamanlis, possessive, vend,
# Nearest to existence: empiricists, principle, idealism, dimmu, quarks, occultism, middens, destinies,
# Nearest to governor: hapsburg, perot, district, kir, terengganu, fend, advice, inserting,
# Nearest to running: toolkit, injure, core, hedley, slick, headset, nextstep, deontological,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0048 0.0854 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9362 0.0859 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0283 0.0848 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0246 0.0815 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0243 0.0861 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9893 0.0886 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9300 0.0870 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9693 0.0863 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9498 0.0869 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9726 0.0858 sec/batch
# Nearest to one: zero, two, eight, three, four, five, seven, nine,
# Nearest to been: extraction, unmentioned, diaries, grounds, inquisitor, bestowed, last, rescind,
# Nearest to united: cuba, jamaica, states, velasco, u, quota, baghd, beacon,
# Nearest to their: ibis, dwellers, puppets, accommodating, gamers, lepers, worshipers, busway,
# Nearest to known: potato, colle, presumed, is, stallion, hershey, bulb, allegories,
# Nearest to states: united, provisions, reluctant, acquisition, unitary, demarcated, ojibwe, bigotry,
# Nearest to at: since, policia, zero, overlord, zurich, diploma, payload, unsold,
# Nearest to other: sap, in, bolivia, valerian, calves, jerome, gnawing, caching,
# Nearest to report: contain, thumbnails, biographies, dupont, extract, muller, perpetrators, pl,
# Nearest to instance: deletions, disengagement, cautionary, momenta, vary, q, vilnius, esl,
# Nearest to animals: mammals, humans, chimpanzees, dualistic, skirmish, graphing, wolves, justifies,
# Nearest to event: fb, nicene, boldness, planting, minimax, seating, coincide, lingered,
# Nearest to paris: haute, dictionnaire, france, arta, migne, prefetch, karamanlis, vend,
# Nearest to existence: idealism, empiricists, principle, quarks, middens, occultism, dimmu, destinies,
# Nearest to governor: hapsburg, perot, district, kir, terengganu, fend, inserting, advice,
# Nearest to running: toolkit, injure, core, headset, hedley, seasons, slick, nextstep,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9838 0.0918 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9937 0.0909 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9783 0.0862 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0125 0.0846 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0401 0.0839 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9556 0.0830 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0258 0.0818 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9863 0.0802 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0061 0.0815 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9806 0.0799 sec/batch
# Nearest to one: zero, eight, two, three, seven, nine, five, four,
# Nearest to been: extraction, unmentioned, diaries, alimentary, inquisitor, last, millionth, mib,
# Nearest to united: cuba, jamaica, states, velasco, u, quota, baghd, beacon,
# Nearest to their: ibis, puppets, dwellers, worshipers, soli, granta, lepers, sha,
# Nearest to known: potato, colle, presumed, stallion, hershey, allegories, bulb, is,
# Nearest to states: united, provisions, reluctant, acquisition, georgia, demarcated, unitary, bigotry,
# Nearest to at: since, policia, felice, zurich, overlord, unsold, excitatory, purposes,
# Nearest to other: in, the, jerome, publically, caching, valerian, sap, bolivia,
# Nearest to report: thumbnails, contain, dupont, biographies, extract, perpetrators, muller, pl,
# Nearest to instance: cautionary, disengagement, deletions, vary, q, momenta, vilnius, settler,
# Nearest to animals: mammals, humans, chimpanzees, wolves, skirmish, dualistic, graphing, justifies,
# Nearest to event: nicene, boldness, fb, archetype, minimax, comprehend, events, planting,
# Nearest to paris: haute, france, dictionnaire, arta, vend, karamanlis, prefetch, monet,
# Nearest to existence: idealism, principle, empiricists, dimmu, quarks, middens, occultism, rejoin,
# Nearest to governor: district, hapsburg, perot, kir, terengganu, fend, inserting, advice,
# Nearest to running: toolkit, injure, hedley, core, headset, seasons, slick, nextstep,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9922 0.0828 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9664 0.0841 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0104 0.0841 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0152 0.0838 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0072 0.0846 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9904 0.0832 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9546 0.0841 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9640 0.0843 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9685 0.0862 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0216 0.0883 sec/batch
# Nearest to one: zero, two, eight, three, seven, nine, five, four,
# Nearest to been: diaries, unmentioned, last, extraction, inquisitor, falsify, rescind, grounds,
# Nearest to united: cuba, states, jamaica, u, velasco, quota, baghd, article,
# Nearest to their: ibis, puppets, drastically, soli, busway, dwellers, sha, worshipers,
# Nearest to known: potato, colle, presumed, is, stallion, hershey, allegories, barada,
# Nearest to states: united, provisions, reluctant, acquisition, demarcated, georgia, hamdi, appeal,
# Nearest to at: policia, since, overlord, felice, zurich, diploma, enrollment, excitatory,
# Nearest to other: in, caching, bolivia, common, sap, publically, the, jerome,
# Nearest to report: contain, thumbnails, perpetrators, biographies, extract, dupont, pl, muller,
# Nearest to instance: cautionary, disengagement, q, deletions, vary, vilnius, comcast, momenta,
# Nearest to animals: mammals, humans, chimpanzees, wolves, graphing, dualistic, skirmish, justifies,
# Nearest to event: boldness, nicene, fb, minimax, andamans, events, planting, archetype,
# Nearest to paris: haute, france, dictionnaire, vend, arta, karamanlis, prefetch, migne,
# Nearest to existence: idealism, empiricists, principle, dimmu, quarks, middens, occultism, destinies,
# Nearest to governor: district, perot, hapsburg, advice, kir, elect, vested, fend,
# ...
# Nearest to been: have, recent, aborigines, unmentioned, was, bicentenary, artificially, even,
# Nearest to united: states, u, kingdom, multiracial, cuba, medal, jamaica, restrictions,
# Nearest to their: ibis, to, other, staffing, hippodrome, worshipers, email, and,
# Nearest to known: as, potato, is, the, presumed, scheme, searchers, yuletide,
# Nearest to states: united, atta, new, us, virginia, reluctant, demarcated, hamdi,
# Nearest to at: the, s, two, zero, since, of, home, three,
# Nearest to other: in, and, the, include, common, to, some, including,
# Nearest to report: thumbnails, recommends, contain, analyses, perpetrators, biographies, commission, radiochemistry,
# Nearest to instance: cautionary, comcast, vilnius, q, augusta, deletions, such, bootlegging,
# Nearest to animals: humans, chimpanzees, graphing, mammals, skirmish, wolves, dualistic, molluscs,
# Nearest to event: events, atp, technetium, boldness, andamans, archetype, nicene, safin,
# Nearest to paris: dictionnaire, gaulle, rieure, nationale, france, haute, montpellier, biochemistry,
# Nearest to existence: dimmu, idealism, belief, includes, veracity, middens, destinies, principle,
# Nearest to governor: inserting, perot, advice, kir, auctioned, hapsburg, leroy, nuncio,
# Nearest to running: toolkit, core, headset, seasons, nextstep, microprocessors, slick, aka,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8256 0.0857 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8404 0.0863 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8747 0.0863 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8692 0.0810 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8686 0.0841 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8821 0.0867 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8552 0.0845 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8604 0.0835 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8814 0.0821 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8624 0.0844 sec/batch
# Nearest to one: two, eight, seven, zero, nine, three, four, five,
# Nearest to been: have, was, arsacid, aborigines, first, recent, zeta, bicentenary,
# Nearest to united: states, kingdom, u, cuba, multiracial, jamaica, medal, uk,
# Nearest to their: ibis, hippodrome, saxons, zsa, drastically, email, ruthless, worshipers,
# Nearest to known: as, potato, presumed, is, searchers, the, allegories, scheme,
# Nearest to states: united, atta, new, us, demarcated, virginia, hamdi, provisions,
# Nearest to at: the, of, s, two, and, home, zurich, policia,
# Nearest to other: and, in, the, include, common, to, some, have,
# Nearest to report: thumbnails, recommends, analyses, perpetrators, radiochemistry, contain, commission, biographies,
# Nearest to instance: vilnius, comcast, q, cautionary, bootlegging, augusta, deletions, phthalocyanine,
# Nearest to animals: humans, chimpanzees, graphing, mammals, molluscs, mariculture, animal, fishkeeping,
# Nearest to event: events, technetium, atp, boldness, safin, archetype, andamans, nicene,
# Nearest to paris: dictionnaire, gaulle, rieure, nationale, france, montpellier, haute, rature,
# Nearest to existence: dimmu, idealism, belief, veracity, brigid, includes, god, limits,
# Nearest to governor: inserting, advice, perot, kir, nuncio, hapsburg, eamon, appointed,
# Nearest to running: toolkit, core, headset, nextstep, seasons, microprocessors, deforest, slick,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8861 0.0858 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8736 0.0842 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8188 0.0841 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8120 0.0840 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9110 0.0849 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8379 0.0839 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9790 0.0864 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8911 0.0936 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8961 0.0850 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7917 0.0839 sec/batch
# Nearest to one: two, eight, zero, three, nine, seven, four, five,
# Nearest to been: have, was, even, claimed, zeta, recent, siona, arsacid,
# Nearest to united: states, u, kingdom, multiracial, cuba, us, medal, motto,
# Nearest to their: hippodrome, saxons, zsa, email, ibis, worshipers, to, staffing,
# Nearest to known: as, the, potato, is, searchers, scheme, presumed, allegories,
# Nearest to states: united, new, atta, us, reluctant, demarcated, hamdi, bigotry,
# Nearest to at: the, s, of, two, and, zero, home, in,
# Nearest to other: in, and, the, common, include, to, some, including,
# Nearest to report: perpetrators, thumbnails, recommends, radiochemistry, commission, analyses, contain, embarrassment,
# Nearest to instance: vilnius, comcast, cautionary, augusta, q, bootlegging, phthalocyanine, deletions,
# Nearest to animals: graphing, humans, chimpanzees, feared, linnaean, fishkeeping, molluscs, mammals,
# Nearest to event: events, atp, technetium, boldness, safin, archetype, andamans, nicene,
# Nearest to paris: dictionnaire, gaulle, nationale, rieure, france, haute, montpellier, galerie,
# Nearest to existence: dimmu, idealism, includes, brigid, veracity, destinies, belief, principle,
# Nearest to governor: inserting, advice, perot, eamon, kir, appointed, leroy, pastor,
# Nearest to running: toolkit, core, headset, seasons, nextstep, dennis, slick, aka,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7879 0.0876 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8510 0.0849 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7995 0.0843 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8715 0.0839 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8292 0.0855 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8796 0.0835 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9247 0.0489 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8332 0.0826 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8618 0.0865 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8353 0.0850 sec/batch
# Nearest to one: eight, nine, two, seven, three, four, zero, five,
# Nearest to been: have, even, arsacid, was, arithmetica, unmentioned, be, claimed,
# Nearest to united: states, u, kingdom, multiracial, cuba, us, medal, jamaica,
# Nearest to their: hippodrome, ibis, saxons, other, worshipers, dwellers, hypnos, drastically,
# Nearest to known: as, the, is, potato, allegories, searchers, presumed, scheme,
# Nearest to states: united, new, atta, us, demarcated, virginia, reluctant, hamdi,
# Nearest to at: s, the, of, in, two, zero, zurich, on,
# Nearest to other: and, in, the, common, include, some, these, to,
# Nearest to report: thumbnails, recommends, perpetrators, radiochemistry, contain, commission, analyses, panel,
# Nearest to instance: vilnius, q, cautionary, bootlegging, augusta, phthalocyanine, comcast, wycliffe,
# Nearest to animals: humans, graphing, chimpanzees, feared, animal, linnaean, predatory, dualistic,
# Nearest to event: events, safin, atp, technetium, boldness, archetype, nicene, andamans,
# Nearest to paris: dictionnaire, gaulle, nationale, rieure, montpellier, france, haute, urs,
# Nearest to existence: dimmu, belief, includes, idealism, unknowable, god, brigid, middens,
# Nearest to governor: inserting, advice, kir, eamon, perot, sumerians, leroy, hapsburg,
# Nearest to running: core, toolkit, headset, microprocessors, nextstep, seasons, dennis, aka,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8473 0.0836 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8021 0.0840 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8048 0.0861 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8040 0.0855 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8581 0.0846 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8333 0.0868 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8518 0.0866 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7382 0.0832 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8243 0.0846 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7893 0.0844 sec/batch
# Nearest to one: two, eight, zero, three, nine, four, seven, five,
# Nearest to been: have, recent, even, arsacid, zeta, first, has, aborigines,
# Nearest to united: states, u, kingdom, cuba, multiracial, us, uk, budweiser,
# Nearest to their: hippodrome, drastically, other, saxons, email, ibis, worshipers, lepers,
# Nearest to known: as, is, the, scheme, potato, an, searchers, allegories,
# Nearest to states: united, atta, new, us, demarcated, bigotry, reluctant, cede,
# Nearest to at: the, s, two, of, zero, in, three, home,
# Nearest to other: in, and, the, common, include, to, some, these,
# Nearest to report: thumbnails, perpetrators, recommends, radiochemistry, analyses, contain, commission, panel,
# Nearest to instance: vilnius, q, augusta, comcast, cautionary, bootlegging, such, wycliffe,
# Nearest to animals: chimpanzees, graphing, humans, feared, assize, dualistic, animal, linnaean,
# Nearest to event: events, atp, technetium, archetype, safin, nicene, andamans, boldness,
# Nearest to paris: dictionnaire, gaulle, nationale, rieure, montpellier, france, haute, urs,
# Nearest to existence: dimmu, includes, belief, idealism, unknowable, brigid, middens, beavers,
# Nearest to governor: inserting, advice, perot, kir, eamon, hapsburg, auctioned, sumerians,
# Nearest to running: core, toolkit, headset, microprocessors, seasons, nextstep, reductio, injure,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7846 0.0849 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8204 0.0872 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8505 0.0855 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8307 0.0801 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8470 0.0825 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8999 0.0847 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8375 0.0851 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8157 0.0842 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8334 0.0810 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8479 0.0794 sec/batch
# Nearest to one: eight, two, zero, three, seven, nine, four, five,
# Nearest to been: have, recent, even, first, intermembrane, has, zeta, bicentenary,
# Nearest to united: states, kingdom, u, cuba, multiracial, us, uk, bootlegged,
# Nearest to their: hippodrome, some, ibis, other, with, are, drastically, dmc,
# Nearest to known: as, the, is, potato, presumed, searchers, scheme, allegories,
# Nearest to states: united, atta, us, new, dawning, reluctant, demarcated, cede,
# Nearest to at: the, two, s, in, zero, three, and, of,
# Nearest to other: and, in, the, common, include, these, some, to,
# Nearest to report: thumbnails, recommends, perpetrators, analyses, commission, radiochemistry, contain, assay,
# Nearest to instance: vilnius, comcast, q, bootlegging, cautionary, justus, augusta, phthalocyanine,
# Nearest to animals: humans, graphing, feared, chimpanzees, assize, bmx, kitchener, fishkeeping,
# Nearest to event: events, atp, technetium, archetype, andamans, safin, bolide, nicene,
# Nearest to paris: dictionnaire, gaulle, nationale, rieure, montpellier, haute, france, monet,
# Nearest to existence: dimmu, includes, idealism, hubble, belief, middens, beavers, veracity,
# Nearest to governor: inserting, perot, eamon, advice, kir, hapsburg, appointed, paine,
# Nearest to running: toolkit, core, headset, microprocessors, seasons, bluntly, nextstep, stalls,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8546 0.0812 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8479 0.0831 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8213 0.0844 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8614 0.0907 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8618 0.0841 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8821 0.0838 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8328 0.0841 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8377 0.0844 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8005 0.0841 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8303 0.0844 sec/batch
# Nearest to one: two, eight, zero, three, seven, nine, four, five,
# Nearest to been: have, recent, even, has, was, first, claimed, recently,
# Nearest to united: states, u, kingdom, us, multiracial, cuba, restrictions, uk,
# Nearest to their: drastically, some, with, they, hippodrome, were, other, become,
# Nearest to known: as, the, is, scheme, on, potato, called, presumed,
# Nearest to states: united, atta, new, us, demarcated, reluctant, dawning, member,
# Nearest to at: the, in, two, s, and, three, zero, of,
# Nearest to other: in, and, the, common, include, some, these, to,
# Nearest to report: recommends, thumbnails, perpetrators, radiochemistry, contain, commission, panel, analyses,
# Nearest to instance: vilnius, bootlegging, q, comcast, be, cautionary, such, augusta,
# Nearest to animals: humans, feared, graphing, chimpanzees, animal, bmx, linnaean, predatory,
# Nearest to event: events, atp, safin, technetium, archetype, andamans, bolide, boldness,
# Nearest to paris: dictionnaire, rieure, nationale, gaulle, montpellier, france, haute, urs,
# Nearest to existence: dimmu, includes, hubble, brigid, beavers, idealism, veracity, middens,
# Nearest to governor: advice, inserting, eamon, kir, perot, appointed, leroy, hapsburg,
# Nearest to running: core, toolkit, headset, microprocessors, reductio, nextstep, dennis, seasons,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8672 0.0877 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7738 0.0869 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9216 0.0850 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9112 0.0852 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8902 0.0847 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8288 0.0826 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7550 0.0852 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8770 0.0864 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7342 0.0845 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8715 0.0844 sec/batch
# Nearest to one: eight, nine, two, seven, zero, three, four, five,
# Nearest to been: have, recent, even, was, recently, has, claimed, zeta,
# Nearest to united: states, u, kingdom, us, multiracial, cuba, motto, jamaica,
# Nearest to their: hippodrome, with, drastically, dmc, other, email, saxons, they,
# Nearest to known: as, is, the, an, potato, searchers, scheme, in,
# Nearest to states: united, new, atta, us, demarcated, virginia, reluctant, eisenstein,
# Nearest to at: s, the, two, in, zero, and, three, of,
# Nearest to other: and, in, the, common, include, these, some, to,
# Nearest to report: recommends, perpetrators, radiochemistry, thumbnails, contain, panel, commission, analyses,
# Nearest to instance: vilnius, bootlegging, q, comcast, be, phthalocyanine, uniquely, such,
# Nearest to animals: humans, feared, graphing, bmx, chimpanzees, assize, animal, linnaean,
# Nearest to event: events, atp, technetium, safin, boldness, bolide, archetype, andamans,
# Nearest to paris: gaulle, dictionnaire, rieure, nationale, france, haute, montpellier, mus,
# Nearest to existence: dimmu, includes, belief, hubble, idealism, brigid, udmurt, lem,
# Nearest to governor: advice, eamon, inserting, kir, leroy, perot, hapsburg, paine,
# Nearest to running: toolkit, core, headset, microprocessors, nextstep, dennis, injure, seasons,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8204 0.0865 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8197 0.0831 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
